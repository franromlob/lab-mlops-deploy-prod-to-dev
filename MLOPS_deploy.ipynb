# %% [markdown]
# """
# PSEUDOCODE — Notebook Overview
#
# 1. Required Packages:
#    - numpy
#    - pandas
#    - matplotlib
#
# 2. Steps Performed:
#    a. Import required libraries
#    b. Create a numeric array from 0 to 9 using numpy
#    c. Compute a mathematical function: y = x^2
#    d. Store results in a pandas DataFrame
#    e. Print the DataFrame to display computed values
#    f. Plot the function y = x^2 using matplotlib
#    g. Show the plot
#
# 3. Expected Output:
#    - A printed table with x and y values
#    - A line plot of the function y = x^2
#
# This notebook is used for the MLOps lab to generate:
#    - A reproducible environment.yml
#    - A simple example of code execution and visualization
# """

# %%
# --- Imports ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# --- Simple mathematical operation ---
# Create an array of numbers from 0 to 9
x = np.arange(0, 10)

# Compute a simple mathematical function
y = x ** 2  # square of each number

# Convert to DataFrame (just to use pandas)
df = pd.DataFrame({"x": x, "y": y})
print("DataFrame with values:")
print(df)

# --- Plot ---
plt.figure(figsize=(6, 4))
plt.plot(x, y, marker='o', color='blue')
plt.title("Function y = x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()
# Out:
# DataFrame with values:
#    x   y
# 0  0   0
# 1  1   1
# 2  2   4
# 3  3   9
# 4  4  16
# 5  5  25
# 6  6  36
# 7  7  49
# 8  8  64
# 9  9  81
